# %% [markdown]
# Is L1:A the machine translation of L2:B? Is L2:B the machine translation of L1:A?
#
# ### Load section information from the source language

# %%
import pandas as pd
import networkx as nx
import json
from collections import Counter
import gzip,json
import re

# %% [markdown]
# ### Select the sections name to be translate
#
# * define targetLang
# * use 'frequency' to filter
# * use percent to filter by %

# %%
def getSectionList(sourceLang,frequency=1,percent=False):
    """
    Use frequency to filter for the number of documents where the section name appears
    use percent to the top % sections
    """
    sectionsTargetAll = []
    sectionsTarget = {}
    c=0
    with gzip.open('../gap/multiLanguageFromDumps/sections-articles_%s.json.gz' % sourceLang) as f: #this for the freq hq articles
        for l in f:
            c+=1
            if c%1000000 == 0: print(c)
            tmp = json.loads(l.decode())
            sectionsTarget[tmp[1]] = tmp[2]
            for secName in tmp[2]:
                    sectionsTargetAll.append(secName.strip())
    sectionsTargetFreq = Counter(sectionsTargetAll)
    #sectionsEnFreq.most_common(50)
    total = sum(sectionsTargetFreq.values())
    acc =0
    secsToEval = []
    for n,(sec,freq) in enumerate(sectionsTargetFreq.most_common()):
        acc+= freq
        secsToEval.append((sec,freq))
        if percent:
            if acc/total > percent: #using sections that cover 80% of total
                print(n)
                print(freq)
                break
        else:
            if freq < frequency:
                print(n)
                print(acc/total)
                break
    return secsToEval

# %% [markdown]
# Translator

# %%
from googletrans import Translator
from random import random
from time import sleep

def getSecsPair(seclist=secsToEval,translateTo='es'):
    """ 
    Source language is detected automatically
    Return a section list in the target language
    """
    print('Wait, translating')
    translator = Translator()
    words = ''
    results = ''
    for n,(section,rank) in enumerate(seclist):
        if len(words) + len(section) < 4900: #max allowed by google
            words += '%d) %s \n' % (n , section)
        else:
            results+= translator.translate(words,dest=translateTo).text +'\n'
            sleep(random() * 5)
            #print(results)
            words = '%d) %s \n' % (n , section)

    results+= translator.translate(words,dest=translateTo).text
    d  = dict(re.findall("(\d+)\) (.+)\n",results))
    translated ={}
    for n,(word,freq)  in enumerate(seclist):
        try:
            translated[word] = d[str(n)]
        except:
            pass
    df = pd.DataFrame.from_dict(translated,orient='index')
    rank = dict([(x,n) for n,(x,y) in enumerate((sorted(seclist,key=lambda s: s[1], reverse=True)))])
    df  = df.join(pd.DataFrame.from_dict(rank,orient='index'),rsuffix='rank')
    df['source'] = df.index
    df = df.sort_values(["0rank"])
    df = df.rename(columns={'0':'result',"0rank":'rank'})
    df = df.set_index("rank")
    print('Finish')
    return df

# %%
def checkBack(langFrom,translateTo,frequency =1):
    """ 
    langFrom: original language
    translateTo: translateTo
    frequency: just consider sections appearing 'frequency' times in the original language
    """
    secsToEval = getSectionList(sourceLang = langFrom,frequency = frequency )
    pairsFirst = getSecsPair(secsToEval,translateTo)
    secsToCheckBack = list(zip(pairsFirst['result'], pairsFirst.index))
    pairsBack = getSecsPair(secsToCheckBack,translateTo=langFrom)
    output = pairsFirst.set_index('result').join(pairsBack.set_index('source'))
    output['compared'] = output.apply(lambda x :True if x['result'] == x['source']  else False, axis=1)
    output['translate'] = output.index
    output.index = output['source'] 
    #sorting back by rank
    pairsFirst['rank'] = pairsFirst.index
    outputSorted =   output.join(pairsFirst[['source','rank']].set_index('source')).set_index('rank').sort_index()
    return outputSorted

# %% [markdown]
# ###  test

# %%
#Catalan to English, min freq=50
df = checkBack('ca','en',50)
# Out:
# 881
# 0.8043961785611913
# Wait, translating
# Finish
# Wait, translating
# Finish

# %%
df
# Out:
#                                 source                                result  \
# rank
# 0                          Referències                           Referències
# 1                           Demografia                            Demografia
# 2                         Bibliografia                          Bibliografia
# 3                             Història                              Història
# 4              Poblacions més properes                    Pobles més propers
# 5                          Vegeu també                           Vegeu també
# 6                            Biografia                             Biografia
# 7                             Economia                              Economia
# 8               Distribució geogràfica                Distribució geogràfica
# 9                           Descripció                            Descripció
# 10                          Morfologia                            Morfologia
# 11    Equipaments sanitaris i escolars         Equipament sanitari i escolar
# 12                             Hàbitat                               Hàbitat
# 13                            Palmarès                              Palmarès
# 14                       Administració                         Administració
# 15                               Notes                                 Notes
# 16                            Argument                              Argument
# 17                         Repartiment                           Repartiment
# 18                               Obres                                 Obres
# 19                        Observacions                          Observacions
# 20                    Enllaços externs                      Enllaços externs
# 21                           Geografia                             Geografia
# 22                    Característiques                      Característiques
# 23                         Trajectòria                           Trajectòria
# 24                                Obra                               Treball
# 25                         Filmografia                           Filmografia
# 26                          Etimologia                            Etimologia
# 27                           Resultats                             Resultats
# 28                Premis i nominacions                  Premis i nominacions
# 29                           Municipis                             Municipis
# ...                                ...                                   ...
# 851                     Llista de reis                        Llista de reis
# 852                            Detalls                               Detalls
# 853                         Integrants                               Membres
# 854         Medallistes més guardonats  La majoria dels premiats medallistes
# 855                            Mètodes                               Mètodes
# 856                    Dades tècniques                       Dades tècniques
# 857                  Descripció física                     Descripció física
# 858           Desenvolupament econòmic              Desenvolupament econòmic
# 859                         Anotacions                            Anotacions
# 860           Organització territorial              Organització territorial
# 861                          Pronòstic                             Pronòstic
# 862                         Postguerra                 Període de postguerra
# 863                   Números musicals                      Números musicals
# 864                            Usuaris                               Usuaris
# 865                            Càrrecs                               Càrrecs
# 866                            Datació                                 Cites
# 867                   Vuitens de final                      Vuit de la final
# 868                          Regulació                             Reglament
# 869                          Urbanisme                             Urbanisme
# 870                              Cites                           Nomenaments
# 871                    Llista de temes                       Llista de temes
# 872                             Trivia                                Trivia
# 873                    Actes destacats               Esdeveniments destacats
# 874                        A Catalunya                           A Catalunya
# 875              Filmografia principal                 Filmografia principal
# 876              Després de la batalla                 Després de la batalla
# 877                           Nutrició                              Nutrició
# 878                             Tribus                                Tribus
# 879                  Carrera artística                     Carrera artística
# 880                            Isòtops                                   NaN
#
#       compared                     translate
# rank
# 0         True                    References
# 1         True                    Demography
# 2         True                  Bibliography
# 3         True                       History
# 4        False                 Nearest towns
# 5         True                      See also
# 6         True                     Biography
# 7         True                       Economy
# 8         True       Geographic distribution
# 9         True                   Description
# 10        True                    Morphology
# 11       False   Health and school equipment
# 12        True                       Habitat
# 13        True                      Palmarés
# 14        True                Administration
# 15        True                         Notes
# 16        True                      Argument
# 17        True                          Cast
# 18        True                         Works
# 19        True                  Observations
# 20        True                External links
# 21        True                     Geography
# 22        True               Characteristics
# 23        True                    Trajectory
# 24       False                          Work
# 25        True                   Filmography
# 26        True                     Etymology
# 27        True                       Results
# 28        True        Prizes and nominations
# 29        True                Municipalities
# ...        ...                           ...
# 851       True                 List of kings
# 852       True                       Details
# 853      False                       Members
# 854      False  Most award-winning medalists
# 855       True                       Methods
# 856       True                Technical data
# 857       True          Physical description
# 858       True          Economic development
# 859       True                   Annotations
# 860       True      Territorial organization
# 861       True                      Forecast
# 862      False                Postwar period
# 863       True               Musical numbers
# 864       True                         Users
# 865       True                       Charges
# 866      False                        Dating
# 867      False            Eight of the final
# 868      False                    Regulation
# 869       True                      Urbanism
# 870      False                  Appointments
# 871       True                List of topics
# 872       True                        Trivia
# 873      False               Featured events
# 874       True                  In Catalonia
# 875       True              Main filmography
# 876       True              After the battle
# 877       True                     Nutrition
# 878       True                        Tribes
# 879       True               Artistic career
# 880      False                      Isotopes
#
# [881 rows x 4 columns]

# %%
#German to English, min freq=50
df = checkBack('de','en',50)
# Out:
# 1000000
# 2000000
# 3000000
# 4000000
# 5000000
# 6000000
# 7000000
# 6669
# 0.8570801038001107
# Wait, translating
# Finish
# Wait, translating
# Finish

# %%
df
# Out:
#                                                  source  \
# rank
# 0                                              Weblinks
# 1                                             Literatur
# 2                                            Geschichte
# 3                                                 Leben
# 4                                       Einzelnachweise
# 5                                            Siehe auch
# 6                                            Geographie
# 7                                              Karriere
# 8                                        Auszeichnungen
# 9                                                 Werke
# 10                                   Sehenswürdigkeiten
# 11                                              Quellen
# 12                                             Handlung
# 13                                         Beschreibung
# 14                                            Geografie
# 15                                            Werdegang
# 16                                              Erfolge
# 17                                              Politik
# 18                                            Schriften
# 19                                                 Lage
# 20                                     Persönlichkeiten
# 21                                          Diskografie
# 22                                Filmografie (Auswahl)
# 23                                     Leben und Wirken
# 24                                              Verkehr
# 25                                             Ehrungen
# 26                                             Merkmale
# 27                                          Hintergrund
# 28                                            Sonstiges
# 29                                      Werke (Auswahl)
# ...                                                 ...
# 6639                                     Akkreditierung
# 6640                                             Kreise
# 6641                               Auswahl-Diskographie
# 6642                                       Fossilbefund
# 6643                                           Das Team
# 6644                             Empfang in Deutschland
# 6645                                           Windpark
# 6646                            Rechtlicher Hintergrund
# 6647                                       Performances
# 6648                                       Nutzerländer
# 6649                               Interessenvertretung
# 6650                             Trikots im Tourverlauf
# 6651                     Denkmalschutz und Fundverbleib
# 6652       Entstehungs- und Veröffentlichungsgeschichte
# 6653  [[Datei:Table tennis pictogram.svg|35px]] Tisc...
# 6654                              Historische Bewertung
# 6655                                            Station
# 6656                               Verbindungsübersicht
# 6657                                 Zukunftsaussichten
# 6658                              Liste der Titelträger
# 6659                                    Entstehungszeit
# 6660                        Kapazität und Infrastruktur
# 6661                         Verbreitung und Unterarten
# 6662                       [[Club de Clichy-Echecs-92]]
# 6663                                     Privates Leben
# 6664                                     Tour de France
# 6665                             Abstammung und Familie
# 6666                                            Vorfeld
# 6667                          Feste und Veranstaltungen
# 6668                                   Besitzgeschichte
#
#                                                  result  compared  \
# rank
# 0                                              Weblinks      True
# 1                                             Literatur      True
# 2                                            Geschichte      True
# 3                                                 Leben      True
# 4                                  individuelle Beweise     False
# 5                                            Siehe auch      True
# 6                                            Geographie      True
# 7                                              Karriere      True
# 8                                        Auszeichnungen      True
# 9                                          funktioniert     False
# 10                                   Sehenswürdigkeiten      True
# 11                                              Quellen      True
# 12                                               Aktion     False
# 13                                         Beschreibung      True
# 14                                           Geographie     False
# 15                                             Karriere     False
# 16                                              Erfolge      True
# 17                                              Politik      True
# 18                                            Schriften      True
# 19                                             Standort     False
# 20                                     Persönlichkeiten      True
# 21                                         Diskographie     False
# 22                             Filmography (selection)      False
# 23                                     Leben und Arbeit     False
# 24                                              Verkehr      True
# 25                                             Ehrungen      True
# 26                                        Eigenschaften     False
# 27                                          Hintergrund      True
# 28                                               Other      False
# 29                                      Werke (Auswahl)      True
# ...                                                 ...       ...
# 6639                                     Accreditation      False
# 6640                                           circles      False
# 6641                             Selection discography      False
# 6642                                   Fossil findings      False
# 6643                                          The team      False
# 6644                              Reception in Germany      False
# 6645                                         wind farm      False
# 6646                                  Legal background      False
# 6647                                      Performances      False
# 6648                                    User countries      False
# 6649                       representation of interests      False
# 6650                           Jerseys during the tour      False
# 6651             monument protection and lost property      False
# 6652                   Genesis and publication history      False
# 6653  [[File: Table tennis pictogram.svg | 35px]] Ta...     False
# 6654                                 Historical review      False
# 6655                                           station      False
# 6656                                Connection overview     False
# 6657                                 Zukunftsaussichten      True
# 6658                             Liste der Titelinhaber     False
# 6659                                     Ursprungsdatum     False
# 6660                        Kapazität und Infrastruktur      True
# 6661                         Verbreitung und Unterarten      True
# 6662                       [[Club de Clichy-Echecs-92]]      True
# 6663                                        Privatleben     False
# 6664                                     Tour de France      True
# 6665                             Abstammung und Familie      True
# 6666                                            Schürze     False
# 6667                          Feste und Veranstaltungen      True
# 6668                                                NaN     False
#
#                                               translate
# rank
# 0                                             Web links
# 1                                            literature
# 2                                                 story
# 3                                                  life
# 4                                     individual proofs
# 5                                              See also
# 6                                             Geography
# 7                                                career
# 8                                                Awards
# 9                                                 works
# 10                                               sights
# 11                                              Sources
# 12                                               action
# 13                                          Description
# 14                                            Geography
# 15                                               career
# 16                                         achievements
# 17                                             Politics
# 18                                             writings
# 19                                             location
# 20                                        personalities
# 21                                          Discography
# 22                              Filmography (selection)
# 23                                        life and work
# 24                                              traffic
# 25                                               Honors
# 26                                             Features
# 27                                           Background
# 28                                                Other
# 29                                    Works (selection)
# ...                                                 ...
# 6639                                      Accreditation
# 6640                                            circles
# 6641                              Selection discography
# 6642                                    Fossil findings
# 6643                                           The team
# 6644                               Reception in Germany
# 6645                                          wind farm
# 6646                                   Legal background
# 6647                                       Performances
# 6648                                     User countries
# 6649                        representation of interests
# 6650                            Jerseys during the tour
# 6651              monument protection and lost property
# 6652                    Genesis and publication history
# 6653  [[File: Table tennis pictogram.svg | 35px]] Ta...
# 6654                                  Historical review
# 6655                                            station
# 6656                                Connection overview
# 6657                                   future prospects
# 6658                               List of titleholders
# 6659                                     date of origin
# 6660                        Capacity and infrastructure
# 6661                        Distribution and subspecies
# 6662                       [[Club de Clichy-Echecs-92]]
# 6663                                       Private life
# 6664                                     Tour de France
# 6665                                 Descent and family
# 6666                                              apron
# 6667                               Festivals and events
# 6668                                   property history
#
# [6658 rows x 4 columns]

# %%
df = checkBack('fa','en',100)
# Out:
# 1000000
# 2000000
# 251
# 0.7644290801033017
# Wait, translating
# Finish
# Wait, translating
# Finish

# %%
df
# Out:
#                                                  source  \
# rank
# 0                                       جستارهای وابسته
# 1                                                 منابع
# 2                                                 جمعیت
# 3                                               خصوصیات
# 4                                                پانویس
# 5                                              نگارخانه
# 6                                              بازیگران
# 7                                               تاریخچه
# 8                                        پیوند به بیرون
# 9                                           مشخصات قنات
# 10                                           زندگی‌نامه
# 11                                            مناسبت‌ها
# 12                                                 آثار
# 13                                                زندگی
# 14                                         خلاصه داستان
# 15                                          خواهرخوانده
# 16                                           فیلم‌شناسی
# 17                                     موقعیت جغرافیایی
# 18                                             رویدادها
# 19                                                جوایز
# 20                                               داستان
# 21                  شرکت‌های هواپیمایی و مقصدهای پروازی
# 22                                               پیشینه
# 23                                               زادگان
# 24                                             افتخارات
# 25                                            زندگینامه
# 26                                        تقسیمات کشوری
# 27                                              جغرافیا
# 28                                           زندگی شخصی
# 29                                           زندگی نامه
# ...                                                 ...
# 221                                                تولد
# 222                                           حمل و نقل
# 223                                        لیست آهنگ‌ها
# 224                                    جُستارهای وابسته
# 225                                                مذهب
# 226                                     جوایز و نامزدها
# 227                                                 نقد
# 228                                             پیشگیری
# 229                                             بازیگری
# 230                                               نتیجه
# 231                                             کاربران
# 232                                               ایران
# 233                                               نمونه
# 234                                          اعضای گروه
# 235                                          شهرستان‌ها
# 236                                            تلویزیون
# 237                                        آثار باستانی
# 238                                            رده‌بندی
# 239                                             آهنگ‌ها
# 240                                           دستاوردها
# 241                                             قسمت‌ها
# 242                                           پانوشت‌ها
# 243   نماینده [[فهرست نمایندگان دوره دهم مجلس شورای ...
# 244                                          صنایع دستی
# 245                                        علائم بالینی
# 246                                       موارد استفاده
# 247                                            الگوریتم
# 248                                             گونه ها
# 249                                           برنامه‌ها
# 250                                            ترجمه‌ها
#
#                                                  result  compared  \
# rank
# 0                                          سوالات مرتبط     False
# 1                                                 منابع      True
# 2                                                 جمعیت      True
# 3                                                مشخصات     False
# 4                                                پاورقی     False
# 5                                                 گالری     False
# 6                                              بازیگران      True
# 7                                               تاریخچه      True
# 8                                          لینک به خارج     False
# 9                                          مشاهده آبشار     False
# 10                                             بیوگرافی     False
# 11                                               مناسبت     False
# 12                                                 آثار      True
# 13                                                زندگی      True
# 14                                                خلاصه     False
# 15                                                خواهر     False
# 16                                           فیلمبرداری     False
# 17                                        محل جغرافیایی     False
# 18                                             رویدادها      True
# 19                                                جوایز      True
# 20                                               داستان      True
# 21                              خطوط هوایی و مقصد پرواز     False
# 22                                             پس زمینه     False
# 23                                                 تولد     False
# 24                                             افتخارات      True
# 25                                             بیوگرافی     False
# 26                                         تقسیمات کشور     False
# 27                                              جغرافیا      True
# 28                                           زندگی شخصی      True
# 29                                             بیوگرافی     False
# ...                                                 ...       ...
# 221                                                تولد      True
# 222                                           حمل و نقل      True
# 223                                       فهرست آهنگ ها     False
# 224                                     عنوان های مرتبط     False
# 225                                                 دین     False
# 226                                    جوایز و نامزدهای     False
# 227                                                 نقد      True
# 228                                             پیشگیری      True
# 229                                               اقدام     False
# 230                                               نتیجه      True
# 231                                             کاربران      True
# 232                                               ایران      True
# 233                                               نمونه      True
# 234                                          اعضای گروه      True
# 235                                               شهرها     False
# 236                                            تلویزیون      True
# 237                                         هنر باستانی     False
# 238                                           طبقه بندی     False
# 239                                             آهنگ ها     False
# 240                                           دستاوردها      True
# 241                                             Backend     False
# 242                                            پانویسها     False
# 243   نماینده [[فهرست نمایندگان دهم مجمع مشورتی اسلا...     False
# 244                                          صنایع دستی      True
# 245                                        علائم بالینی      True
# 246                                      استفاده می کند     False
# 247                                            الگوریتم      True
# 248                                             گونه ها      True
# 249                                           برنامه ها     False
# 250                                                 NaN     False
#
#                                               translate
# rank
# 0                                     Related Questions
# 1                                             Resources
# 2                                            population
# 3                                        Specifications
# 4                                              Footnote
# 5                                               Gallery
# 6                                                  Cast
# 7                                               History
# 8                                   Link to the outside
# 9                                  View of the aqueduct
# 10                                            Biography
# 11                                            Occasions
# 12                                                Works
# 13                                                 Life
# 14                                             Synopsis
# 15                                               Sister
# 16                                          Filmography
# 17                                  Geographic location
# 18                                               Events
# 19                                               Awards
# 20                                                Story
# 21                     Airlines and flight destinations
# 22                                           Background
# 23                                               births
# 24                                               Honors
# 25                                            Biography
# 26                                    Country divisions
# 27                                            Geography
# 28                                        Personal life
# 29                                            Biography
# ...                                                 ...
# 221                                               Birth
# 222                                            Shipping
# 223                                       List of songs
# 224                                      Related Titles
# 225                                            Religion
# 226                              Awards and nominations
# 227                                              Review
# 228                                          Prevention
# 229                                              Acting
# 230                                          The result
# 231                                               users
# 232                                                Iran
# 233                                              Sample
# 234                                Members of the group
# 235                                              cities
# 236                                                  TV
# 237                                         Ancient art
# 238                                      Classification
# 239                                               Songs
# 240                                        Achievements
# 241                                             Backend
# 242                                           Footnotes
# 243   Representative [[List of Representatives of th...
# 244                                         Handicrafts
# 245                                      Clinical signs
# 246                                                Uses
# 247                                           algorithm
# 248                                             Species
# 249                                            Programs
# 250                                        translations
#
# [250 rows x 4 columns]
