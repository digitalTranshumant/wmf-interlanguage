# %% [markdown]
# Is L1:A the machine translation of L2:B? Is L2:B the machine translation of L1:A?
#
# ### Load section information from the source language

# %%
import pandas as pd
import networkx as nx
import json
from collections import Counter
import gzip,json
import re

# %% [markdown]
# ### Select the sections name to be translate
#
# * define targetLang
# * use 'frequency' to filter
# * use percent to filter by %

# %%
def getSectionList(sourceLang,frequency=1,percent=False):
    """
    Use frequency to filter for the number of documents where the section name appears
    use percent to the top % sections
    """
    sectionsTargetAll = []
    sectionsTarget = {}
    c=0
    with gzip.open('../gap/multiLanguageFromDumps/sections-articles_%s.json.gz' % sourceLang) as f: #this for the freq hq articles
        for l in f:
            c+=1
            if c%1000000 == 0: print(c)
            tmp = json.loads(l.decode())
            sectionsTarget[tmp[1]] = tmp[2]
            for secName in tmp[2]:
                    sectionsTargetAll.append(secName.strip())
    sectionsTargetFreq = Counter(sectionsTargetAll)
    #sectionsEnFreq.most_common(50)
    total = sum(sectionsTargetFreq.values())
    acc =0
    secsToEval = []
    for n,(sec,freq) in enumerate(sectionsTargetFreq.most_common()):
        acc+= freq
        secsToEval.append((sec,freq))
        if percent:
            if acc/total > percent: #using sections that cover 80% of total
                print(n)
                print(freq)
                break
        else:
            if freq < frequency:
                print(n)
                print(acc/total)
                break
    return secsToEval

# %% [markdown]
# Translator

# %%
from googletrans import Translator
from random import random
from time import sleep

def getSecsPair(seclist=secsToEval,translateTo='es'):
    """ 
    Source language is detected automatically
    Return a section list in the target language
    """
    print('Wait, translating')
    translator = Translator()
    words = ''
    results = ''
    for n,(section,rank) in enumerate(seclist):
        if len(words) + len(section) < 4900: #max allowed by google
            words += '%d) %s \n' % (n , section)
        else:
            results+= translator.translate(words,dest=translateTo).text +'\n'
            sleep(random() * 5)
            #print(results)
            words = '%d) %s \n' % (n , section)

    results+= translator.translate(words,dest=translateTo).text
    d  = dict(re.findall("(\d+)\) (.+)\n",results))
    translated ={}
    for n,(word,freq)  in enumerate(seclist):
        try:
            translated[word] = d[str(n)]
        except:
            pass
    df = pd.DataFrame.from_dict(translated,orient='index')
    rank = dict([(x,n) for n,(x,y) in enumerate((sorted(seclist,key=lambda s: s[1], reverse=True)))])
    df  = df.join(pd.DataFrame.from_dict(rank,orient='index'),rsuffix='rank')
    df['source'] = df.index
    df = df.sort_values(["0rank"])
    df = df.rename(columns={'0':'result',"0rank":'rank'})
    df = df.set_index("rank")
    print('Finish')
    return df

# %%
def checkBack(langFrom,translateTo,frequency =1):
    """ 
    langFrom: original language
    translateTo: translateTo
    frequency: just consider sections appearing 'frequency' times in the original language
    """
    secsToEval = getSectionList(sourceLang = langFrom,frequency = frequency )
    pairsFirst = getSecsPair(secsToEval,translateTo)
    secsToCheckBack = list(zip(pairsFirst['result'], pairsFirst.index))
    pairsBack = getSecsPair(secsToCheckBack,translateTo=langFrom)
    output = pairsFirst.set_index('result').join(pairsBack.set_index('source'))
    output['compared'] = output.apply(lambda x :True if x['result'] == x['source']  else False, axis=1)
    output['translate'] = output.index
    output.index = output['source'] 
    #sorting back by rank
    pairsFirst['rank'] = pairsFirst.index
    outputSorted =   output.join(pairsFirst[['source','rank']].set_index('source')).set_index('rank').sort_index()
    return outputSorted

# %% [markdown]
# ###  test

# %%
#Catalan to English, min freq=50
catToEn = checkBack('ca','en',100)
# Out:
# 515
# 0.7810210701625164
# Wait, translating
# Finish
# Wait, translating
# Finish

# %%
catToEn
# Out:
#                                 source                         result  \
# rank
# 0                          Referències                    Referències
# 1                           Demografia                     Demografia
# 2                         Bibliografia                   Bibliografia
# 3                             Història                       Història
# 4              Poblacions més properes             Pobles més propers
# 5                          Vegeu també                    Vegeu també
# 6                            Biografia                      Biografia
# 7                             Economia                       Economia
# 8               Distribució geogràfica         Distribució geogràfica
# 9                           Descripció                     Descripció
# 10                          Morfologia                     Morfologia
# 11    Equipaments sanitaris i escolars  Equipament sanitari i escolar
# 12                             Hàbitat                        Hàbitat
# 13                            Palmarès                       Palmarès
# 14                       Administració                  Administració
# 15                               Notes                          Notes
# 16                            Argument                       Argument
# 17                         Repartiment                    Repartiment
# 18                               Obres                          Obres
# 19                        Observacions                   Observacions
# 20                    Enllaços externs               Enllaços externs
# 21                           Geografia                      Geografia
# 22                    Característiques               Característiques
# 23                         Trajectòria                    Trajectòria
# 24                                Obra                        Treball
# 25                         Filmografia                    Filmografia
# 26                          Etimologia                     Etimologia
# 27                           Resultats                      Resultats
# 28                Premis i nominacions           Premis i nominacions
# 29                           Municipis                      Municipis
# ...                                ...                            ...
# 485              Personatges destacats          Personatges destacats
# 486                    Situació actual                Situació actual
# 487          Resultats i Classificació      Resultats i classificació
# 488                Activitat i difusió            Activitat i difusió
# 489                      Interpretació                  Interpretació
# 490                        Programació                    Programació
# 491                        Altres usos                    Altres usos
# 492                         Golejadors                       Objectiu
# 493                        Governadors                    Governadors
# 494            Classificacions annexes       Classificacions adjuntes
# 495                            Partits                        Partits
# 496                        Denominació                    Denominació
# 497                             Llista                         Llista
# 498                            Creació                        Creació
# 499                          Moviments                      Moviments
# 500             Ciutats i zones rurals         Ciutats i zones rurals
# 501                           Resultat                       Resultat
# 502                    Estats sobirans                Estats sobirans
# 503                             Òperes                         òperes
# 504           Resultats a la Fórmula 1       Resultats a la Fórmula 1
# 505                             Proves                         Proves
# 506                     Fets Destacats                 Fets destacats
# 507                             Lletra                          Carta
# 508                            Tècnica                        Tècnica
# 509                            Estrena                       Premiere
# 510                  Consell municipal                     Ajuntament
# 511              Classificació General          Classificació general
# 512             Descripció lingüística         Descripció lingüística
# 513                     Quadre d'honor                 Imatge d'honor
# 514              Segona Guerra Mundial                            NaN
#
#       compared                    translate
# rank
# 0         True                   References
# 1         True                   Demography
# 2         True                 Bibliography
# 3         True                      History
# 4        False                Nearest towns
# 5         True                     See also
# 6         True                    Biography
# 7         True                      Economy
# 8         True      Geographic distribution
# 9         True                  Description
# 10        True                   Morphology
# 11       False  Health and school equipment
# 12        True                      Habitat
# 13        True                     Palmarés
# 14        True               Administration
# 15        True                        Notes
# 16        True                     Argument
# 17        True                         Cast
# 18        True                        Works
# 19        True                 Observations
# 20        True               External links
# 21        True                    Geography
# 22        True              Characteristics
# 23        True                   Trajectory
# 24       False                         Work
# 25        True                  Filmography
# 26        True                    Etymology
# 27        True                      Results
# 28        True       Prizes and nominations
# 29        True               Municipalities
# ...        ...                          ...
# 485       True       Outstanding characters
# 486       True            Current situation
# 487      False   Results and Classification
# 488       True   Activity and dissemination
# 489       True               Interpretation
# 490       True                  Programming
# 491       True                   Other uses
# 492      False                         Goal
# 493       True                    Governors
# 494      False     Attached Classifications
# 495       True                      Matches
# 496       True                 Denomination
# 497       True                         List
# 498       True                     Creation
# 499       True                    Movements
# 500       True       Cities and rural areas
# 501       True                       Result
# 502       True             Sovereign States
# 503      False                       Operas
# 504       True         Results in Formula 1
# 505       True                        Tests
# 506      False               Featured facts
# 507      False                       Letter
# 508       True                    Technique
# 509      False                     Premiere
# 510      False            Municipal Council
# 511      False       General Classification
# 512       True       Linguistic description
# 513      False             Picture of honor
# 514      False             Second World War
#
# [515 rows x 4 columns]

# %%
catToEn.compared.value_counts()
# Out:
# True     414
# False    101
# Name: compared, dtype: int64

# %%
#German to English, min freq=100
deToEn = checkBack('de','en',100)
# Out:
# 1000000
# 2000000
# 3000000
# 4000000
# 5000000
# 6000000
# 7000000
# 3938
# 0.84050065556761
# Wait, translating
# Finish
# Wait, translating
# Finish

# %%
deToEn
# Out:
#                              source                        result  compared  \
# rank
# 0                          Weblinks                      Weblinks      True
# 1                         Literatur                     Literatur      True
# 2                        Geschichte                    Geschichte      True
# 3                             Leben                         Leben      True
# 4                   Einzelnachweise          individuelle Beweise     False
# 5                        Siehe auch                    Siehe auch      True
# 6                        Geographie                    Geographie      True
# 7                          Karriere                      Karriere      True
# 8                    Auszeichnungen                Auszeichnungen      True
# 9                             Werke                  funktioniert     False
# 10               Sehenswürdigkeiten            Sehenswürdigkeiten      True
# 11                          Quellen                       Quellen      True
# 12                         Handlung                        Aktion     False
# 13                     Beschreibung                  Beschreibung      True
# 14                        Geografie                    Geographie     False
# 15                        Werdegang                      Karriere     False
# 16                          Erfolge                       Erfolge      True
# 17                          Politik                       Politik      True
# 18                        Schriften                     Schriften      True
# 19                             Lage                      Standort     False
# 20                 Persönlichkeiten              Persönlichkeiten      True
# 21                      Diskografie                  Diskographie     False
# 22            Filmografie (Auswahl)      Filmography (selection)      False
# 23                 Leben und Wirken              Leben und Arbeit     False
# 24                          Verkehr                       Verkehr      True
# 25                         Ehrungen                      Ehrungen      True
# 26                         Merkmale                 Eigenschaften     False
# 27                      Hintergrund                   Hintergrund      True
# 28                        Sonstiges                        Andere     False
# 29                  Werke (Auswahl)               Werke (Auswahl)      True
# ...                             ...                           ...       ...
# 3908           Aussichtsmöglichkeit             view possibility      False
# 3909                    In der Nähe                       Nearby      False
# 3910                Stil und Inhalt            style and content      False
# 3911         Berufliche Tätigkeiten      Professional activities      False
# 3912                        Auswahl                    selection      False
# 3913            Werke (auf Deutsch)            Works (in German)      False
# 3914               Boote der Klasse           boats of the class      False
# 3915                        Juroren                       jurors      False
# 3916  Charts und Chartplatzierungen  charts and chart placements      False
# 3917           Formationsgeschichte            formation history      False
# 3918                    Grabstätten                        tombs      False
# 3919                          Küche                      kitchen      False
# 3920         Veröffentlichte Spiele              Published Games      False
# 3921             Turnier der Frauen           Women's tournament      False
# 3922     Weitere Sehenswürdigkeiten                 Other sights      False
# 3923                Bekannte Alumni            Well-known alumni      False
# 3924                     Bundesliga                   Bundesliga      False
# 3925                       Formel 1                    Formula 1      False
# 3926                       Lizenzen                     licenses      False
# 3927                     Abschnitte                     sections      False
# 3928                    Juniorinnen                 junior women      False
# 3929           Historische Bauwerke         Historical buildings      False
# 3930                         Gospel                       Gospel      False
# 3931                         Hütten                         huts      False
# 3932               Resultate Männer                  Results Men      False
# 3933                  Draftergebnis               Drafter result      False
# 3934       Zubringer und Umgehungen          Feeder and bypasses      False
# 3935           Gäste und Mitglieder           guests and members      False
# 3936           Forschungsleistungen            Research Services      False
# 3937                    Begegnungen                           NaN     False
#
#                         translate
# rank
# 0                       Web links
# 1                      literature
# 2                           story
# 3                            life
# 4               individual proofs
# 5                        See also
# 6                       Geography
# 7                          career
# 8                          Awards
# 9                           works
# 10                         sights
# 11                        Sources
# 12                         action
# 13                    Description
# 14                      Geography
# 15                         career
# 16                   achievements
# 17                       Politics
# 18                       writings
# 19                       location
# 20                  personalities
# 21                    Discography
# 22        Filmography (selection)
# 23                  life and work
# 24                        traffic
# 25                         Honors
# 26                       Features
# 27                     Background
# 28                          Other
# 29              Works (selection)
# ...                           ...
# 3908             view possibility
# 3909                       Nearby
# 3910            style and content
# 3911      Professional activities
# 3912                    selection
# 3913            Works (in German)
# 3914           boats of the class
# 3915                       jurors
# 3916  charts and chart placements
# 3917            formation history
# 3918                        tombs
# 3919                      kitchen
# 3920              Published Games
# 3921           Women's tournament
# 3922                 Other sights
# 3923            Well-known alumni
# 3924                   Bundesliga
# 3925                    Formula 1
# 3926                     licenses
# 3927                     sections
# 3928                 junior women
# 3929         Historical buildings
# 3930                       Gospel
# 3931                         huts
# 3932                  Results Men
# 3933               Drafter result
# 3934          Feeder and bypasses
# 3935           guests and members
# 3936            Research Services
# 3937                   encounters
#
# [3933 rows x 4 columns]

# %%
deToEn.compared.value_counts()
# Out:
# False    2063
# True     1870
# Name: compared, dtype: int64

# %%
#Farsi to English

# %%
faToEn = checkBack('fa','en',100)
# Out:
# 1000000
# 2000000
# 251
# 0.7644290801033017
# Wait, translating
# Finish
# Wait, translating
# Finish

# %%
faToEn
# Out:
#                                                  source  \
# rank
# 0                                       جستارهای وابسته
# 1                                                 منابع
# 2                                                 جمعیت
# 3                                               خصوصیات
# 4                                                پانویس
# 5                                              نگارخانه
# 6                                              بازیگران
# 7                                               تاریخچه
# 8                                        پیوند به بیرون
# 9                                           مشخصات قنات
# 10                                           زندگی‌نامه
# 11                                            مناسبت‌ها
# 12                                                 آثار
# 13                                                زندگی
# 14                                         خلاصه داستان
# 15                                          خواهرخوانده
# 16                                           فیلم‌شناسی
# 17                                     موقعیت جغرافیایی
# 18                                             رویدادها
# 19                                                جوایز
# 20                                               داستان
# 21                  شرکت‌های هواپیمایی و مقصدهای پروازی
# 22                                               پیشینه
# 23                                               زادگان
# 24                                             افتخارات
# 25                                            زندگینامه
# 26                                        تقسیمات کشوری
# 27                                              جغرافیا
# 28                                           زندگی شخصی
# 29                                           زندگی نامه
# ...                                                 ...
# 221                                                تولد
# 222                                           حمل و نقل
# 223                                        لیست آهنگ‌ها
# 224                                    جُستارهای وابسته
# 225                                                مذهب
# 226                                     جوایز و نامزدها
# 227                                                 نقد
# 228                                             پیشگیری
# 229                                             بازیگری
# 230                                               نتیجه
# 231                                             کاربران
# 232                                               ایران
# 233                                               نمونه
# 234                                          اعضای گروه
# 235                                          شهرستان‌ها
# 236                                            تلویزیون
# 237                                        آثار باستانی
# 238                                            رده‌بندی
# 239                                             آهنگ‌ها
# 240                                           دستاوردها
# 241                                             قسمت‌ها
# 242                                           پانوشت‌ها
# 243   نماینده [[فهرست نمایندگان دوره دهم مجلس شورای ...
# 244                                          صنایع دستی
# 245                                        علائم بالینی
# 246                                       موارد استفاده
# 247                                            الگوریتم
# 248                                             گونه ها
# 249                                           برنامه‌ها
# 250                                            ترجمه‌ها
#
#                                                  result  compared  \
# rank
# 0                                          سوالات مرتبط     False
# 1                                                 منابع      True
# 2                                                 جمعیت      True
# 3                                                مشخصات     False
# 4                                                پاورقی     False
# 5                                                 گالری     False
# 6                                              بازیگران      True
# 7                                               تاریخچه      True
# 8                                          لینک به خارج     False
# 9                                          مشاهده آبشار     False
# 10                                             بیوگرافی     False
# 11                                               مناسبت     False
# 12                                                 آثار      True
# 13                                                زندگی      True
# 14                                                خلاصه     False
# 15                                                خواهر     False
# 16                                           فیلمبرداری     False
# 17                                        محل جغرافیایی     False
# 18                                             رویدادها      True
# 19                                                جوایز      True
# 20                                               داستان      True
# 21                              خطوط هوایی و مقصد پرواز     False
# 22                                             پس زمینه     False
# 23                                                 تولد     False
# 24                                             افتخارات      True
# 25                                             بیوگرافی     False
# 26                                         تقسیمات کشور     False
# 27                                              جغرافیا      True
# 28                                           زندگی شخصی      True
# 29                                             بیوگرافی     False
# ...                                                 ...       ...
# 221                                                تولد      True
# 222                                           حمل و نقل      True
# 223                                       فهرست آهنگ ها     False
# 224                                     عنوان های مرتبط     False
# 225                                                 دین     False
# 226                                    جوایز و نامزدهای     False
# 227                                                 نقد      True
# 228                                             پیشگیری      True
# 229                                               اقدام     False
# 230                                               نتیجه      True
# 231                                             کاربران      True
# 232                                               ایران      True
# 233                                               نمونه      True
# 234                                          اعضای گروه      True
# 235                                               شهرها     False
# 236                                            تلویزیون      True
# 237                                         هنر باستانی     False
# 238                                           طبقه بندی     False
# 239                                             آهنگ ها     False
# 240                                           دستاوردها      True
# 241                                             Backend     False
# 242                                            پانویسها     False
# 243   نماینده [[فهرست نمایندگان دهم مجمع مشورتی اسلا...     False
# 244                                          صنایع دستی      True
# 245                                        علائم بالینی      True
# 246                                      استفاده می کند     False
# 247                                            الگوریتم      True
# 248                                             گونه ها      True
# 249                                           برنامه ها     False
# 250                                                 NaN     False
#
#                                               translate
# rank
# 0                                     Related Questions
# 1                                             Resources
# 2                                            population
# 3                                        Specifications
# 4                                              Footnote
# 5                                               Gallery
# 6                                                  Cast
# 7                                               History
# 8                                   Link to the outside
# 9                                  View of the aqueduct
# 10                                            Biography
# 11                                            Occasions
# 12                                                Works
# 13                                                 Life
# 14                                             Synopsis
# 15                                               Sister
# 16                                          Filmography
# 17                                  Geographic location
# 18                                               Events
# 19                                               Awards
# 20                                                Story
# 21                     Airlines and flight destinations
# 22                                           Background
# 23                                               births
# 24                                               Honors
# 25                                            Biography
# 26                                    Country divisions
# 27                                            Geography
# 28                                        Personal life
# 29                                            Biography
# ...                                                 ...
# 221                                               Birth
# 222                                            Shipping
# 223                                       List of songs
# 224                                      Related Titles
# 225                                            Religion
# 226                              Awards and nominations
# 227                                              Review
# 228                                          Prevention
# 229                                              Acting
# 230                                          The result
# 231                                               users
# 232                                                Iran
# 233                                              Sample
# 234                                Members of the group
# 235                                              cities
# 236                                                  TV
# 237                                         Ancient art
# 238                                      Classification
# 239                                               Songs
# 240                                        Achievements
# 241                                             Backend
# 242                                           Footnotes
# 243   Representative [[List of Representatives of th...
# 244                                         Handicrafts
# 245                                      Clinical signs
# 246                                                Uses
# 247                                           algorithm
# 248                                             Species
# 249                                            Programs
# 250                                        translations
#
# [250 rows x 4 columns]

# %%
faToEn.compared.value_counts()
# Out:
# False    134
# True     116
# Name: compared, dtype: int64
